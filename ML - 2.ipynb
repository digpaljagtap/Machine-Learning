# %%
import numpy

# %% [markdown]
# ## Percentile

# %%
# What is the age that 75% of the people are younger than?

a = (5,67,45,3,45,67,34,28,21,20,67,45,34,65,76,34,23,45,34,75)

b = numpy.percentile(a,75)

print(b)
# Out:
# 65.5

# %% [markdown]
# ## Data Distribution

# %% [markdown]
# Create an array containing 100 random floats between 0 and 5:

# %%
x = numpy.random.uniform(0.0, 5.0, 100)

print(x)
# Out:
# [4.33802356 3.72899958 3.37401477 2.21129352 3.56492979 1.09006986
#  2.32109296 0.50744339 4.40149028 3.88393491 0.0643467  4.29841073
#  4.06474191 1.43404314 1.21173669 1.40866865 2.409469   0.48089312
#  4.60598857 0.36051073 1.33520637 1.28767693 4.03404129 3.04799801
#  1.67110851 4.68964245 3.39481098 0.43939527 1.18640187 0.23467896
#  1.72684312 0.53128609 4.10450219 0.92810575 2.22494662 4.17665059
#  4.86342555 0.54978574 1.88031289 2.50824234 4.98490523 2.01408569
#  0.60455601 4.56029646 4.10677045 1.21559567 4.72193896 2.58975615
#  1.18536499 2.90563394 1.64955464 2.17488144 1.92844931 0.92265231
#  4.03391479 4.81907453 0.41566194 3.94674247 0.79522646 1.22989962
#  1.9997767  3.98799953 1.38262643 3.14207944 1.06352193 3.59699429
#  4.79918239 2.26171601 1.88427562 2.95995801 4.62603952 3.52704094
#  4.53987089 2.82844356 2.99419549 4.57217098 4.14846832 0.57227147
#  1.90355913 1.03621299 0.89677016 0.72719965 2.51158113 2.00021569
# ...

# %% [markdown]
# ## Histogram
#
# To visualize the data set we can draw a histogram with the data we collected.

# %%
import matplotlib.pyplot as plt

x = numpy.random.uniform(0 ,5 ,100)

print(x)

plt.hist(x, 5)
plt.show()
# Out:
# [3.86318443 1.60685488 3.91062371 3.89877565 4.64234476 1.89093793
#  3.92785243 4.99739013 3.07724537 0.43124322 0.89833511 1.89870505
#  3.25152873 2.9981934  3.81381187 3.05355778 2.87968027 1.86625082
#  4.68680408 0.33284133 0.97679856 3.20052191 3.70293492 3.46254447
#  1.08725804 3.31612226 3.48314779 4.90129957 3.42306992 3.75160127
#  2.50552017 2.68437433 1.88971745 2.04166572 3.92600117 4.40038891
#  0.73596778 1.36675289 1.18148199 4.6980485  2.26739457 2.27776958
#  4.0958081  4.83766612 1.98513561 4.94281794 1.39515735 4.12095378
#  0.45863431 0.91403222 0.33029396 3.84506791 2.25711    0.25720696
#  3.587407   2.58575926 2.93315441 3.83185184 2.95051082 1.37968561
#  3.41540788 2.33948973 0.26923225 4.70663809 0.71213288 1.32355394
#  0.1513392  1.8831511  1.41283963 0.20628433 0.58774895 2.47399763
#  4.36985369 2.00020537 0.60169622 1.60981356 0.07394502 0.59806498
#  3.03497353 1.85109231 0.3584954  4.77272545 2.58251659 4.2060251
# ...

# %% [markdown]
# We use the array from the example above to draw a histogram with 5 bars.
#
# The first bar represents how many values in the array are between 0 and 1.
#
# The second bar represents how many values are between 1 and 2.
#
# Etc.
#
# Which gives us this result:
#
# #### 21 values are between 0 and 1
# #### 24 values are between 1 and 2
# #### 17 values are between 2 and 3
# #### 20 values are between 3 and 4
# #### 18 values are between 4 and 5

# %%
x = numpy.random.uniform(0 ,10 ,100000)

plt.hist(x , 100)
plt.show()

# %% [markdown]
# ## Normal Data Distribution
#
# how to create an array where the values are concentrated around a given value.
#
# In probability theory this kind of data distribution is known as the normal data distribution, or the Gaussian data distribution

# %%
x = numpy.random.normal(5 ,1 ,100000)

plt.hist(x , 100)
plt.show()

# %% [markdown]
# specify that the mean value is 5.0, and the standard deviation is 1.0.
#
# Meaning that the values should be concentrated around 5.0, and rarely further away than 1.0 from the mean.
#
# And as you can see from the histogram, most values are between 4.0 and 6.0, with a top at approximately 5.0.
